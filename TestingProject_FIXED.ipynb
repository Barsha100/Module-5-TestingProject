# %% [markdown]
# # Module 5 Programming Assignment - Testing
#
# **Student Name:** Barsha Bhandari
# **Course:** Software Development Using Python
# **Instructor:** Mr. Lonnie Clifton
# **Submission Date:** April 5, 2026
#
# ## Purpose
# The purpose of this assignment is to practice and implement testing in Python. I completed the required sections:
# - Testing Your Code
# - Writing Your First Test
# - Executing Your First Test
#
# Because `unittest` works best in a regular Python script, I created and ran the tests in VS Code, then documented the work in this notebook.

# %% [markdown]
# ## 1. Python Program Used for Testing (`calculator.py`)
#
# The following Python script was created in VS Code and saved as `calculator.py`.

# %%
"""calculator.py - simple functions for Module 5 testing assignment."""

def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    return a / b

def concat_as_strings(a, b):
    return str(a) + str(b)

def swap_values(a, b):
    return b, a

# %% [markdown]
# ## 2. Unit Test File (`test_calculator.py`)
#
# The following test file was created in VS Code and saved as `test_calculator.py`.

# %%
"""test_calculator.py - unit tests for calculator.py."""

import unittest
import calculator


class TestCalculator(unittest.TestCase):

    def test_addition(self):
        self.assertEqual(calculator.add(7, 3.5), 10.5)

    def test_subtraction(self):
        self.assertEqual(calculator.subtract(7, 3.5), 3.5)

    def test_multiplication(self):
        self.assertEqual(calculator.multiply(7, 3.5), 24.5)

    def test_division(self):
        self.assertEqual(calculator.divide(7, 3.5), 2.0)

    def test_string_concat(self):
        self.assertEqual(calculator.concat_as_strings(7, 3.5), "73.5")

    def test_swap(self):
        self.assertEqual(calculator.swap_values(15, 4), (4, 15))


if __name__ == "__main__":
    unittest.main()

# %% [markdown]
# ## 3. Example Test Execution in VS Code
#
# I ran the following command in the VS Code terminal:
#
# ```bash
# python -m unittest test_calculator.py
# ```
#
# ### Expected Output
# ```text
# ......
# ----------------------------------------------------------------------
# Ran 6 tests in 0.000s
#
# OK
# ```

# %% [markdown]
# ## 4. Test Results in My Own Words
#
# The test results mean that each test case checked one part of the program and all of them passed successfully. The six dots show that six separate tests were executed without failure. The message **“Ran 6 tests”** confirms how many tests were performed, and **“OK”** means the code produced the expected results for every test.
#
# These results show that the program is working correctly for addition, subtraction, multiplication, division, string conversion, and value swapping. Unit testing is useful because it helps verify that the program behaves as expected and makes it easier to find problems if the code changes later.
